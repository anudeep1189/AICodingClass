# %% [markdown]
# # heading 1

# %%
print("Hello")
# Out:
# Hello

# %%
print("hi","Hello","name")
# Out:
# hi Hello name

# %%
print("hi","hello","hey",sep=' | ')
# Out:
# hi | hello | hey

# %%
print("hi","hello","hey",end=' -TheEnd ')
# Out:
# hi hello hey -TheEnd

# %%
a = 5
print(a)
# Out:
# 5

# %%
print("value of a is ",a)
# Out:
# value of a is  5

# %%
print(f"The Value of {a}")
# Out:
# The Value of 5

# %%
b = input()
print(b)
# Out:
# 11

# %%
a = input()
b = input()

print(a,b)
# Out:
# 11 12

# %%
marks = 10.10
rank = 2
print(f'marks {marks},type={type(marks)}')
print(f'rank {rank},type={type(rank)}')
# Out:
# marks 10.1,type=<class 'float'>
# rank 2,type=<class 'int'>

# %%
flag = True
print(flag,type(flag))
# Out:
# True <class 'bool'>

# %%
fruits=['apple','mango','abc','xyz',123,67.89,True]
print(fruits,type(fruits))
# Out:
# ['apple', 'mango', 'abc', 'xyz', 123, 67.89, True] <class 'list'>

# %%
fruits[1]
# Out:
# 'mango'

# %%
fruits[0:3]
# Out:
# ['apple', 'mango', 'abc']

# %%
fruits[3] = 'nothing'
fruits
# Out:
# ['apple', 'mango', 'abc', 'nothing', 123, 67.89, True]

# %%
fruits.pop()
fruits
# Out:
# ['apple', 'mango', 'abc', 'nothing', 123, 67.89]

# %%
fruits.append('new append')
fruits
# Out:
# ['apple', 'mango', 'abc', 'nothing', 123, 67.89, 'new append', 'new append']

# %%
fruits.reverse()
fruits
# Out:
# ['new append', 'new append', 67.89, 123, 'nothing', 'abc', 'mango', 'apple']

# %%
# immutable 
#tuples
t1 = (1,2,3.4,'hello',2)
print(t1,type(t1))
# Out:
# (1, 2, 3.4, 'hello', 2) <class 'tuple'>

# %%
t1.count(2)
# Out:
# 2

# %%
t1.index(2)
# Out:
# 1

# %%
#only stores the unique value
set1={1,2,3,4,5,6,1,1,1,1}
set1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#only unique from both
set2={9,12,14,15,1,2,3}
set3 = set1.union(set2)
set3
# Out:
# {1, 2, 3, 4, 5, 6, 9, 12, 14, 15}

# %%
set1.add(44)
set1
# Out:
# {2, 3, 4, 5, 6, 44, 55}

# %%
set4 = set1.difference(set2)
print(set1,set2,set3)
# Out:
# {2, 3, 4, 5, 6, 55, 44} {1, 2, 3, 9, 12, 14, 15} {1, 2, 3, 4, 5, 6, 9, 12, 14, 15}

# %%
set5 = set1.intersection(set2)
set5
# Out:
# {2, 3}
